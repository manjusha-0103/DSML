# %% [markdown]
# <a href="https://colab.research.google.com/github/mgkcode/DSML/blob/main/covin.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv("/content/drive/MyDrive/dsbdl/pract/mini-project/miniproject1/Analysis on COVID-19 Vaccination /archive/covid_vaccine_statewise.csv")
df.head(100)
# Out:
#     Updated On  State  Total Doses Administered    Sessions   Sites   \
# 0   16/01/2021  India                   48276.0      3455.0   2957.0
# 1   17/01/2021  India                   58604.0      8532.0   4954.0
# 2   18/01/2021  India                   99449.0     13611.0   6583.0
# 3   19/01/2021  India                  195525.0     17855.0   7951.0
# 4   20/01/2021  India                  251280.0     25472.0  10504.0
# ..         ...    ...                       ...         ...      ...
# 95  21/04/2021  India               129646105.0   9537781.0  67123.0
# 96  22/04/2021  India               132754608.0  10459336.0  73933.0
# 97  23/04/2021  India               135658324.0   9772224.0  68575.0
# 98  24/04/2021  India               138185956.0   8300170.0  59612.0
# 99  25/04/2021  India               139185173.0   5844983.0  41927.0
#
#     First Dose Administered  Second Dose Administered  \
# 0                   48276.0                       0.0
# ...

# %%
df.isnull().sum()
df["Sessions"].plot()

# %%
df_state.describe()
# Out:
#                                          Total Doses Administered  \
#                                                             count
# State
# Andaman and Nicobar Islands                                 206.0
# Andhra Pradesh                                              206.0
# Arunachal Pradesh                                           206.0
# Assam                                                       206.0
# Bihar                                                       206.0
# Chandigarh                                                  206.0
# Chhattisgarh                                                206.0
# Dadra and Nagar Haveli and Daman and Diu                    205.0
# Delhi                                                       206.0
# Goa                                                         206.0
# Gujarat                                                     206.0
# Haryana                                                     206.0
# ...

# %%
df_state = df.groupby("State")
if df_state["State"] != "India":
    first_dose = df_state[["First Dose Administered"]].sum()
    print("The list of persons state wise vaccinated for first dose in India : \n",first_dose)
# Out:
# The list of persons state wise vaccinated for first dose in India :
#                                            First Dose Administered
# State
# Andaman and Nicobar Islands                          1.642585e+07
# Andhra Pradesh                                       1.232861e+09
# Arunachal Pradesh                                    4.900498e+07
# Assam                                                5.856002e+08
# Bihar                                                1.470503e+09
# Chandigarh                                           4.470310e+07
# Chhattisgarh                                         7.960029e+08
# Dadra and Nagar Haveli and Daman and Diu             3.359506e+07
# Delhi                                                6.243395e+08
# Goa                                                  7.599137e+07
# Gujarat                                              2.131646e+09
# Haryana                                              7.557984e+08
# ...

# %%
if df_state["State"] != "India":
    second_dose = df_state["Second Dose Administered"].sum()
    print("The list of persons state wise vaccinated for first dose in India : \n",second_dose)
# Out:
# The list of persons state wise vaccinated for first dose in India :
#  State
# Andaman and Nicobar Islands                 4.118554e+06
# Andhra Pradesh                              3.588176e+08
# Arunachal Pradesh                           1.193232e+07
# Assam                                       1.307888e+08
# Bihar                                       2.707906e+08
# Chandigarh                                  1.159374e+07
# Chhattisgarh                                1.721204e+08
# Dadra and Nagar Haveli and Daman and Diu    4.594416e+06
# Delhi                                       1.882189e+08
# Goa                                         1.619817e+07
# Gujarat                                     6.004184e+08
# Haryana                                     1.586561e+08
# Himachal Pradesh                            7.383858e+07
# India                                       6.759621e+09
# Jammu and Kashmir                           8.595165e+07
# ...

# %%
df_first = (df[["First Dose Administered"]] == "India")
df_first
# Out:
#       First Dose Administered
# 0                       False
# 1                       False
# 2                       False
# 3                       False
# 4                       False
# ...                       ...
# 7840                    False
# 7841                    False
# 7842                    False
# 7843                    False
# 7844                    False
#
# [7845 rows x 1 columns]

# %%
print("Number of Males vaccinated : ")
print("\n")
#if df_state("State") == "India" :
print(df["Male(Individuals Vaccinated)"].sum())
# Out:
# Number of Males vaccinated :
#
#
# 7138698858.0

# %%
df["Female(Individuals Vaccinated)"].sum()
# Out:
# 6321628736.0
